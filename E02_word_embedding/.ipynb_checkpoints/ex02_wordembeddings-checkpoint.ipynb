# %%
import numpy as np
import pandas as pd
import re
import string
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset,DataLoader, random_split
from collections import Counter, OrderedDict
from tqdm import tqdm
import matplotlib.pyplot as plt
#from nltk.tokenize import word_tokenize

torch.manual_seed(1)

# %% [markdown]
# # **Define some parameters**

# %%
WINDOW_SIZE = 2
EMBEDDING_SIZE = 50
BATCH_SIZE = 256
EPOCH=1

# %% [markdown]
# # **Define classes and functions**
#
# **Note: I don't split dataset into training and validation sets because the cuda memory isn't enough to hold the training. In order to get the best epoch, I check the performance with different iterations (see result in report).**

# %%
# define class Text2Dataset 
class Text2DataSet(Dataset):

    def __init__(self, data_file_path, content_type='reviews', window_size=2):

        # read files and lower the case
        if content_type=='reviews':
          f = pd.read_csv(data_file_path)
          review = f['Review'].tolist()
          text = ' '.join(review).lower()
        elif content_type=='scifi': 
          with open(data_file_path,'r',encoding='utf-8') as f:
            text = f.read().lower()
        else:
          print('Define correct content_type to select the file.')
        
        # remove numbers
        text = re.sub(r'[0-9]+','',text)
        
        # remove punctuation
        table = str.maketrans('', '', string.punctuation)
        words = [w.translate(table) for w in text.split()]

        self.count_word = Counter(words)
        self.vocab = set(words)
        self.vocab_size = len(self.vocab)
        self.word_to_idx = {word: i for i, word in enumerate(self.vocab)}
        self.idx_to_word = list(self.word_to_idx.keys()) 
        self.window_size = window_size

        self.context_target =  [([words[i-(j+1)] for j in range(window_size)] +\
                                 [words[i+(j+1)] for j in range(window_size)],
                                words[i])
                                for i in range(window_size, len(words)-window_size)]

    def __getitem__(self, idx):
        context = torch.tensor([self.word_to_idx[w] for w in self.context_target[idx][0]])
        target = torch.tensor([self.word_to_idx[self.context_target[idx][1]]])
        return context, target

    def __len__(self):
        return len(self.context_target)
      


# define class of CBOW
class CBOW(nn.Module):
    def __init__(self, vocab_size, embedding_size, window_size):
        super(CBOW, self).__init__()
        self.embeddings = nn.Embedding(vocab_size, embedding_size)
        self.linear = nn.Linear(embedding_size, vocab_size)
    
    def forward(self, inputs):
        embeds = torch.sum(self.embeddings(inputs), dim=1)     # sum of input tensors
        out = self.linear(embeds)
        log_probs = F.log_softmax(out, dim=1)
        return log_probs


# define function to train the cbow model
def train_cbow(data, vocab_size, vocab_to_idx, embedding_size, window_size, epoch=EPOCH):
    model = CBOW(vocab_size,embedding_size, window_size)
    
    nll_loss = nn.NLLLoss()    # negative log loss
    #optimizer = optim.SGD(cbow.parameters(), lr=0.001)
    optimizer = optim.Adam(model.parameters(), lr=0.01)

    cuda_available = torch.cuda.is_available()
    data_loader = DataLoader(data, batch_size=BATCH_SIZE, shuffle=True)

    for epo in range(epoch):
        total_loss = 0
        for context, target in tqdm(data_loader):
          if context.size()[0] != BATCH_SIZE:
            continue
          # continue training with last several instances if the number of them less than batch size
          if cuda_available:
            context = context.cuda()
            target = target.squeeze(1).cuda()
            model = model.cuda()          

          model.zero_grad()
          log_prob = model(context)
          loss = nll_loss(log_prob, target)
          loss.backward()
          optimizer.step()
          total_loss += loss    
        average_loss = total_loss / len(data_loader)  

        print("{}/{} average loss {:.4f}".format(epo+1, epoch, average_loss))
    
    return model


# search words with different frequencies
def search_words_in_different_frequencies(words_dict, high_bar=20000, 
                                  low_bar=50, median_bar=[1000,5000]):
  high = []
  median = []
  rare = []
  for word, count in words_dict.items():
    if count > high_bar:
      high.append(word)
    elif count > median_bar[0] and count < median_bar[1]:
      median.append(word)
    elif count < low_bar:
      rare.append(word)
  return high, median, rare


# K-nearest neighbor to get top similar words of certain word
def get_closest_word(model, idx_to_word, idx, topn=5): 
  embed_matrix = model.embeddings.weight.detach().cpu().numpy()
  dists = np.dot((embed_matrix - embed_matrix[idx])**2, np.ones(embed_matrix.shape[1]))
  idxs = np.argsort(dists)[1:topn+1]
  #print('The {} nearest neighbour of {} are: '.format(str(topn), idx_to_word[idx]))
  closest_words = []
  for i in idxs:
    closest_words.append(idx_to_word[i])
  print(closest_words)
  return closest_words

# %% [markdown]
# # ***Corpus: tripadvisor hotel reviews***
#
# ---
#
#
# # **Preprocess and load data of tripadvisor hotel reviews**
# **Preprocess and load data**

# %%
# load dataset hotel reviews
reviews = Text2DataSet('tripadvisor_hotel_reviews.csv',content_type='reviews',window_size=WINDOW_SIZE)

# %% [markdown]
# **get variables needed for model training**

# %%
vocab_size_rev = reviews.vocab_size
word_to_idx_rev = reviews.word_to_idx
idx_to_word_rev = reviews.idx_to_word
print(vocab_size_rev)
# Out:
# 76101

# %% [markdown]
# # **Train model on the hotel reviews**

# %%
# train model on dataset of hotel reviews, 10 epochs
model_rev = train_cbow(reviews, vocab_size_rev, word_to_idx_rev, EMBEDDING_SIZE, WINDOW_SIZE, epoch=EPOCH)
# Out:
# 100%|██████████| 8204/8204 [01:27<00:00, 93.82it/s]
# 1/1 average loss 7.5667

# %% [markdown]
# # **Search words in different frequencies in corpus hotel reviews**

# %%
# get the statistics of word counts
rev_words_dict = reviews.count_word
pd.DataFrame(rev_words_dict.values()).describe()
# Out:
#                   0
# count  76101.000000
# mean      27.596944
# std      372.244207
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        3.000000
# max    48864.000000

# %%
# looking for words with different frequencies
high_rev, low_rev, rare_rev = search_words_in_different_frequencies(rev_words_dict,high_bar=15000 ,
                                                          median_bar=[300,500], low_bar=5)
print("high frequency:", high_rev)
print("low frequency:", low_rev)
print("rare:", rare_rev)
# Out:
# high frequency: ['hotel', 'good', 'stay', 'room', 'not', 'great', 'staff', 'nt']
# low frequency: ['anniversary', 'valet', 'talking', 'advantage', 'longer', 'member', 'chain', 'showed', 'oh', 'mixed', 'calls', 'asking', 'provide', 'furnished', 'concerned', 'neighborhood', 'picky', 'saying', 'champagne', 'chocolate', 'trips', 'screen', 'rates', 'sound', 'filled', 'w', 'driver', 'downside', 'picked', 'broken', 'face', 'play', 'hair', 'sleeping', 'wireless', 'comments', 'language', 'company', 'lights', 'hit', 'online', 'word', 'design', 'opinion', 'welcoming', 'art', 'chance', 'interesting', 'options', 'museum', 'experienced', 'exceptional', 'sheets', 'foot', 'bell', 'travelers', 'slept', 'july', 'pleasantly', 'reserved', 'hall', 'waited', 'noticed', 'dollar', 'credit', 'checkout', 'gift', 'earlier', 'man', 'didnçé', 'bag', 'gets', 'sent', 'sunday', 'apparently', 'downstairs', 'closer', 'unfortunately', 'lady', 'aware', 'treated', 'lucky', 'entrance', 'nearly', 'finding', 'thanks', 'spending', 'attitude', 'means', 'personal', 'machine', 'stylish', 'imagine', 'forward', 'sister', 'recommendations', 'base', 'luxurious', 'regular', 'supposed', 'gone', 'add', 'comfort', 'total', 'itçé', 'points', 'equipped', 'jacuzzi', 'stand', 'donçé', 'surprise', 'thoroughly', 'option', 'centrally', 'queen', 'future', 'following', 'north', 'literally', 'higher', 'possible', 'reasonably', 'totally', 'lower', 'buildings', 'save', 'willing', 'ago', 'kitchen', 'buses', 'handy', 'opposite', 'terrific', 'slightly', 'union', 'bay', 'sightseeing', 'appointed', 'marble', 'toiletries', 'stairs', 'gem', 'steps', 'families', 'overpriced', 'write', 'pizza', 'sign', 'march', 'appreciated', 'rating', 'range', 'lift', 'carpet', 'worse', 'prior', 'low', 'obviously', 'pressure', 'advisor', 'mention', 'cable', 'similar', 'flowers', 'added', 'simple', 'usual', 'idea', 'mean', 'accomodating', 'immaculate', 'facing', 'advance', 'fully', 'boutique', 'outdoor', 'offers', 'incredible', 'reserve', 'sized', 'tours', 'generally', 'issues', 'happened', 'pictures', 'list', 'woman', 'visiting', 'south', 'tables', 'sink', 'traffic', 'annoying', 'expecting', 'bigger', 'additional', 'terrace', 'share', 'beat', 'miss', 'month', 'opened', 'feet', 'living', 'important', 'attention', 'tourists', 'hyatt', 'returning', 'excursions', 'roof', 'romantic', 'complete', 'sites', 'beware', 'planning', 'smaller', 'fan', 'traveling', 'deluxe', 'information', 'suggest', 'august', 'perfectly', 'clear', 'friday', 'arriving', 'arrive', 'employees', 'elevators', 'members', 'common', 'agree', 'ordered', 'security', 'catch', 'notice', 'somewhat', 'conference', 'pastries', 'exactly', 'executive', 'spectacular', 'fast', 'smoking', 'consider', 'smoke', 'clothes', 'saturday', 'red', 'twin', 'closet', 'bugs', 'fee', 'streets', 'fixed', 'ceiling', 'fair', 'bought', 'april', 'board', 'basically', 'older', 'feeling', 'numerous', 'trees', 'junior', 'complained', 'tips', 'maintained', 'meant', 'careful', 'guys', 'meet', 'delivered', 'serve', 'breakfasts', 'stores', 'typical', 'general', 'traveled', 'transportation', 'renovated', 'mall', 'brilliant', 'works', 'channels', 'sights', 'agent', 'pass', 'questions', 'summer', 'heat', 'disappointing', 'europe', 'locals', 'biggest', 'june', 'sports', 'comes', 'normal', 'running', 'reviewers', 'awful', 'section', 'caribbean', 'forget', 'situated', 'transport', 'glad', 'straight', 'beautifully', 'superior', 'incredibly', 'minor', 'speaking', 'sea', 's', 'minibar', 'various', 'sort', 'ground', 'treat', 'lost', 'difference', 'adults', 'round', 'considering', 'allowed', 'wide', 'directions', 'taxis', 'travelling', 'taste', 'river', 'seeing', 'nightly', 'stops', 'strong', 'choices', 'bottles', 'apart', 'moment', 'comment', 'apple', 'setting', 'wow', 'waves', 'cooked', 'trouble', 'travelled', 'worried', 'lines', 'months', 'chicken', 'whilst', 'massage', 'bread', 'seafood', 'princess', 'orleans', 'stocked', 'rain', 'bottled', 'managed', 'buffets', 'italy', 'dr', 'rum', 'chinese', 'majestic', 'inclusive', 'lobster', 'bartenders', 'disco', 'madrid', 'las', 'garde ...
# rare: ['bangs', 'hood', 'chating', 'bagsprior', 'comfortablenot', 'acheat', 'controlsthis', 'levelpositives', 'pillowsattentive', 'staffnegatives', 'requeststv', 'showerbefore', 'arrivalcheckin', 'disappointingin', 'forgottenthe', 'brandi', 'pattens', 'palatte', 'seahawk', 'arabic', 'promply', 'humpin', 'mantained', 'bernard', 'besite', 'emotions', 'fantanned', 'joliet', 'oenophilesatisfying', 'smackagainst', 'handblown', 'ridewe', 'longish', 'midsection', 'proportions', 'optionsa', 'chocked', 'quickley', 'relates', 'homegreat', 'theather', 'wellpikes', 'mono', 'sturdiness', 'needlelittle', 'grocerydrug', 'ppmarket', 'quotient', 'overpaying', 'qualitywise', 'pointsmiles', 'benaroya', 'phonecalls', 'faxes', 'warwck', 'lenora', 'okbut', 'disppointment', 'envisioned', 'jiggly', 'flatrate', 'referrals', 'semifuncitional', 'outsourced', 'troubleshooting', 'dared', 'smirking', 'kittycorner', 'eliptical', 'sazerac', 'hmmmmm', 'patterns', 'vibrated', 'annoyingon', 'creamers', 'classyfriday', 'restall', 'gfriend', 'bumbershoot', 'airporter', 'twoperson', 'glassenclosed', 'companyservice', 'flinchgym', 'goldçé', 'distancegastronomy', 'amusingthis', 'gfriends', 'bedlinens', 'touchyou', 'helens', 'hoffstadt', 'checkbox', 'sheeeesh', 'roomsif', 'getway', 'anywho', 'panaroma', 'outrage', 'juliet', 'balconylove', 'dahlia', 'storeminimart', 'marketon', 'availablei', 'handyoverall', 'areahotel', 'makerparking', 'airconditionera', 'intruder', 'inchesthe', 'ralph', 'cafethere', 'ironwork', 'acquire', 'needlebest', 'convenientwould', 'acually', 'cinerama', 'nordstroms', 'elevatoricethe', 'andstated', 'andpressing', 'conservation', 'facet', 'needsattention', 'askew', 'aadvantage', 'ointment', 'shocks', 'bandaid', 'skeleton', 'powers', 'seattlewhere', 'hairbut', 'okbecause', 'cringeshe', 'sanitizer', 'spraythe', 'shag', 'wallit', 'inchesi', 'boucy', 'gravitated', 'requestedit', 'moron', 'interview', 'committing', 'floormat', 'roomlocation', 'unmatchable', 'seattlewent', 'bacco', 'superably', 'welcomingour', 'wellmannered', 'anythingit', 'etta', 'shea', 'watermarket', 'ferriesoh', 'viewsa', 'amy', 'timealthought', 'wynn', 'worned', 'dhalia', 'lunatic', 'transcon', 'prebookedthis', 'kells', 'injust', 'taxexcellent', 'hutch', 'prevailthe', 'finein', 'eitherit', 'wellnormally', 'tl', 'canlis', 'charmer', 'pergola', 'handicrafts', 'tablesour', 'pedestaltype', 'spreading', 'tableshelf', 'lowestpriced', 'peoplewatching', 'beiges', 'blacks', 'predominating', 'marketthe', 'fountainsculpture', 'operateswe', 'eyecontact', 'atsome', 'monstrous', 'undating', 'socal', 'uncooperative', 'tempurpedic', 'ranier', 'vineyard', 'shepard', 'fairey', 'chargingç', 'loadingdelivery', 'downed', 'roommates', 'woodden', 'grunge', 'nightsta', 'cyclops', 'runofthe', 'ubercool', 'crossreference', 'inference', 'shelling', 'didanyway', 'outlining', 'compensatory', 'macrina', 'breakfastbrunchlunch', 'wtih', 'goodsall', 'foodies', 'localsthe', 'toofor', 'stylie', 'sepcial', 'turntables', 'cardiac', 'inducing', 'nontraditional', 'aceit', 'viewbut', 'zoe', 'marketpike', 'downtownif', 'apathy', 'sorrys', 'rectangle', 'shapethe', 'noisythis', 'stype', 'travelbusiness', 'hiltoni', 'vacuums', 'chattering', 'sensefinally', 'freed', 'corian', 'eyemask', 'seattlewelcome', 'earlyevening', 'findcentral', 'spacioustry', 'palatablerestaurant', 'timesaver', 'nonqualifying', 'smokein', 'carcinogenic', 'throats', 'drythe', 'okthere', 'badas', 'locationsuite', 'shotupon', 'uhoh', 'hurriedly', 'bedthis', 'anacortes', 'sante', 'beforei', 'rundownmy', 'itby', 'aptstyle', 'amreported', 'roominess', 'lodgings', 'cityit', 'priests', 'nuns', 'priestsour', 'bellboyadam', 'rarethis', 'transportations', 'markey', 'waterfrontif', 'rushhour', 'bedsok', 'bathroomok', 'kitchenettethe', 'awaywhat', 'dana', 'conveniant', 'compementary', 'hooters', 'needleanders', 'overbookingi', 'wote', 'rhe', 'brigeta', 'scrambe', 'annei', 'unforgivable', 'resevation', 'guarenteeing', 'scanlonsan', 'midjanuary', 'fielded', 'someth ...

# %% [markdown]
# # **Predict top 5 closest words by model trained on hotel reviews**

# %%
# top 5 closest words predicted by model trained on dataset of hotel reviews
chosen_rev_words = ['hotel','good','stay','hair','exceptional','imagine','emotions','overpaying','shocks']
for word in chosen_rev_words:
  print("{}:{}".format(word, rev_words_dict[word]))
  get_closest_word(model_rev, idx_to_word_rev, word_to_idx_rev[word])
  print('\n')
# Out:
# hotel:48864
# ['resort', 'place', 'property', 'thought', 'rooms']
#
#
# good:16986
# ['great', 'fine', 'excellent', 'better', 'average']
#
#
# stay:15158
# ['staying', 'return', 'come', 'actually', 'visit']
#
#
# hair:339
# ['specific', 'dark', 'missing', 'furniture', 'fact']
#
#
# exceptional:380
# ['outstanding', 'excellent', 'personal', 'nice', 'superb']
#
#
# imagine:355
# ['believe', 'afford', 'remember', 'comment', 'say']
#
#
# emotions:3
# ['lobbyentertainmentfood', 'disapointment', 'rolls', 'clips', 'ap']
#
#
# overpaying:2
# ['continually', 'refurbished', 'whats', 'goodnatured', 'gluten']
#
#
# shocks:3
# ['washrooms', 'walls', 'restraunt', 'permanently', 'border']

# %% [markdown]
# # ***Corpus: Scifi***
#
# ---
#
#
# # **Preprocess and load the data of scifi**
# **Preprocess and load data**

# %%
# load scifi dataset
scifi = Text2DataSet('scifi.txt',content_type='scifi',window_size=WINDOW_SIZE)

# %% [markdown]
# **get variables needed for model training**

# %%
vocab_size_scifi = scifi.vocab_size
word_to_idx_scifi = scifi.word_to_idx
idx_to_word_scifi = scifi.idx_to_word
print(vocab_size_scifi)
# Out:
# 200808

# %% [markdown]
# # **Train model on scifi**

# %%
# train model on scifi dataset
model_scifi = train_cbow(scifi, vocab_size_scifi, word_to_idx_scifi, EMBEDDING_SIZE, WINDOW_SIZE)
# Out:
# 100%|██████████| 60110/60110 [25:32<00:00, 39.21it/s]
# 1/1 average loss 6.7511

# %% [markdown]
# # **Search words in different frequencies in corpus scifi**

# %%
# get the statistics of word counts
scifi_words_dict = scifi.count_word
pd.DataFrame(scifi_words_dict.values()).describe()
# Out:
#                    0
# count  200808.000000
# mean       76.630508
# std      3077.862353
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         5.000000
# max    883836.000000

# %%
# looking for words with different frequencies
high_sci, low_sci, rare_sci = search_words_in_different_frequencies(scifi_words_dict,high_bar= 10000,
                                                          median_bar=[500,800], low_bar=5)
print("high frequency:", high_sci)
print("low frequency:", low_sci)
print("rare:", rare_sci)
# Out:
# high frequency: ['', 'all', 'new', 'and', 'if', 'is', 'by', 'no', 'for', 'as', 'at', 'in', 'us', 'of', 'this', 'are', 'any', 'to', 'a', 'with', 'the', 'i', 'was', 'after', 'much', 'thought', 'because', 'its', 'on', 'it', 'will', 'be', 'that', 'just', 'had', 'into', 'we', 'have', 'very', 'people', 'which', 'them', 'their', 'now', 'one', 'our', 'why', 'you', 'say', 'would', 'not', 'but', 'get', 'from', 'or', 'think', 'some', 'could', 'then', 'so', 'has', 'dont', 'than', 'other', 'like', 'own', 'way', 'what', 'make', 'while', 'still', 'must', 'an', 'who', 'when', 'they', 'do', 'over', 'his', 'he', 'without', 'around', 'good', 'old', 'there', 'only', 'thats', 'want', 'out', 'little', 'been', 'last', 'nothing', 'more', 'time', 'too', 'years', 'go', 'look', 'back', 'your', 'come', 'him', 'eyes', 'looked', 'made', 'away', 'man', 'up', 'face', 'three', 'men', 'were', 'knew', 'room', 'said', 'voice', 'off', 'before', 'went', 'head', 'turned', 'came', 'again', 'im', 'these', 'first', 'asked', 'world', 'about', 'something', 'know', 'himself', 'did', 'tell', 'mind', 'thing', 'my', 'youre', 'two', 'me', 'long', 'where', 'take', 'her', 'going', 'she', 'well', 'got', 'down', 'how', 'through', 'door', 'hand', 'right', 'cant', 'can', 'didnt', 'left', 'enough', 'those', 'never', 'life', 'see', 'here', 'found', 'even', 'might', 'another', 'course', 'took', 'few', 'ship', 'earth']
# low frequency: ['publishing', 'inc', 'post', 'subscription', 'canada', 'elsewhere', 'persons', 'title', 'selected', 'cup', 'aid', 'market', 'share', 'greatest', 'instance', 'print', 'personality', 'practice', 'plot', 'described', 'concept', 'logical', 'created', 'modern', 'amazing', 'fix', 'pride', 'rooms', 'firing', 'harsh', 'overhead', 'clothing', 'concrete', 'stiff', 'spoken', 'replaced', 'seated', 'avoid', 'lieutenant', 'facing', 'blank', 'boss', 'spare', 'quarter', 'seriously', 'gift', 'peter', 'swallowed', 'answers', 'relax', 'yesterday', 'pack', 'dreams', 'grown', 'buried', 'coat', 'strip', 'kitchen', 'match', 'flame', 'thumb', 'hanging', 'wearily', 'trail', 'shift', 'university', 'letters', 'extended', 'badly', 'lab', 'k', 'crack', 'deadly', 'collection', 'jaw', 'trade', 'wise', 'shoved', 'apparent', 'inch', 'cigarette', 'dim', 'flash', 'prof', 'numbers', 'dragged', 'hero', 'rubbed', 'chin', 'assistant', 'degrees', 'forty', 'martin', 'mess', 'whos', 'guys', 'folded', 'husband', 'allow', 'announced', 'stated', 'leading', 'enter', 'honest', 'statement', 'signed', 'sealed', 'instrument', 'refused', 'knocked', 'rage', 'hoping', 'ignored', 'bunch', 'recently', 'item', 'court', 'scientist', 'floating', 'ray', 'angle', 'handsome', 'damage', 'former', 'thoughtfully', 'telephone', 'tossed', 'rid', 'lovely', 'purple', 'worn', 'bought', 'becoming', 'shoes', 'slim', 'letting', 'signs', 'items', 'trial', 'enjoy', 'cases', 'gaze', 'exact', 'lunch', 'greg', 'hiding', 'intended', 'discover', 'happening', 'scream', 'consciousness', 'excited', 'peered', 'picking', 'basis', 'cheek', 'confused', 'faintly', 'deeply', 'flow', 'crime', 'freedom', 'iv', 'glowing', 'bubble', 'trace', 'missing', 'helpless', 'arthur', 'mighty', 'clock', 'wear', 'sister', 'male', 'mixed', 'stranger', 'lots', 'poured', 'tough', 'explanation', 'random', 'growth', 'deeper', 'breakfast', 'strode', 'dirty', 'growled', 'commissioner', 'ends', 'row', 'release', 'mister', 'false', 'development', 'organization', 'ing', 'devil', 'concern', 'television', 'losing', 'additional', 'argument', 'deliberately', 'excellent', 'grimly', 'automatically', 'slip', 'grip', 'calls', 'wire', 'assumed', 'california', 'uh', 'responsible', 'college', 'promised', 'nowhere', 'circumstances', 'nonsense', 'authority', 'endless', 'washington', 'wrist', 'alarm', 'grin', 'split', 'opportunity', 'hat', 'block', 'response', 'bell', 'marked', 'breaking', 'rules', 'stairs', 'woods', 'bedroom', 'average', 'completed', 'discovery', 'wood', 'located', 'design', 'harder', 'contained', 'reaching', 'sank', 'fill', 'blackness', 'panic', 'thoroughly', 'function', 'events', 'complicated', 'electric', 'terror', 'fist', 'superior', 'swiftly', 'chances', 'roar', 'naked', 'dug', 'alert', 'gives', 'sheet', 'motor', 'roll', 'established', 'tied', 'sake', 'pause', 'mention', 'released', 'earthmen', 'dare', 'darling', 'limited', 'rear', 'wheel', 'rolling', 'driving', 'traffic', 'eleven', 'warned', 'engine', 'backward', 'shelter', 'clearing', 'gradually', 'objects', 'bringing', 'co', 'rack', 'vessel', 'sprang', 'cast', 'sweat', 'lip', 'tightly', 'everywhere', 'relaxed', 'straightened', 'silly', 'quit', 'forgot', 'halfway', 'roared', 'whirled', 'orange', 'beast', 'kissed', 'gentle', 'games', 'puzzled', 'assured', 'lowered', 'setting', 'reply', 'craft', 'degree', 'immediate', 'horizon', 'don', 'noted', 'bitterly', 'satisfaction', 'mirror', 'background', 'gathered', 'opinion', 'observed', 'smart', 'soil', 'receive', 'studying', 'taught', 'murmured', 'beauty', 'spend', 'favor', 'soul', 'crawled', 'cross', 'slammed', 'trained', 'fed', 'tore', 'explosion', 'useless', 'saved', 'suspected', 'serve', 'humanity', 'fault', 'cautiously', 'stirred', 'hasnt', 'comfortable', 'gestured', 'suggest', 'chairs', 'laws', 'instructions', 'respect', 'officers', 'dress', 'glasses', 'drunk', 'liquid', 'senses', 'strain', 'nearby', 'advance', 'character', 'equally', 'choose', 'destruction', 'ours', 'rule', 'bound', 'races', 'success', 'failure', ...
# rare: ['aiiow', 'fcopy', 'fieldwide', 'storyline', 'exhort', 'storyidea', 'zerg', 'incompatable', 'timetables', 'wuthering', 'climaxes', 'debil', 'everlengthening', 'lovetriangle', 'cordelps', 'howbe', 'exfanzine', 'enthusiasms', 'outshade', 'sfunned', 'hiseyes', 'rpofe', 'halfwits', 'goofball', 'fivefifteen', 'ino', 'didrpt', 'uhhunh', 'hisway', 'affixing', 'sorer', 'acquittal', 'twocolumn', 'uilty', 'wastp', 'fireless', 'gnize', 'hersmooth', 'ringless', 'longshoreman', 'droppingyou', 'fronuher', 'necesi', 'exolf', 'promavoided', 'quirking', 'ieutenant', 'traightened', 'guiltier', 'hiim', 'onlya', 'corroborating', 'conof', 'rienee', 'cynica', 'jusizzbajiwm', 'tti', 'cii', 'ripia', 'straig', 'misto', 'pubbound', 'torials', 'cupfuls', 'conit', 'durin', 'ured', 'unmoral', 'fifit', 'tripledistilled', 'somebodybought', 'troys', 'mosscolored', 'broadloom', 'halfback', 'heavyfeatured', 'reddishblond', 'inyou', 'sainted', 'chauns', 'leprechaun', 'insinu', 'hokeypokey', 'stranthis', 'beyou', 'corwho', 'delps', 'ima', 'mimeograp', 'corde', 'sma', 'shewas', 'dakins', 'ngernail', 'decorne', 'sity', 'codiscoverers', 'slife', 'suffere', 'nent', 'leaftrial', 'tranpaul', 'corto', 'letthree', 'liello', 'furness', 'beyeah', 'fou', 'worldrenow', 'scientis', 'trys', 'evidenceevidence', 'therk', 'ivarned', 'warnin', 'wnt', 'laundries', 'washinh', 'slaking', 'chenowichs', 'washin', 'relieutenant', 'alized', 'quited', 'walkup', 'ruleabiding', 'alor', 'inline', 'tumblertype', 'thinedged', 'hanlater', 'tastemodem', 'mopporbe', 'tofive', 'nightgowns', 'ingaccount', 'bavin', 'rockribbed', 'batik', 'wopd', 'countersunk', 'vvt', 'nded', 'voliin', 'estab', 'lours', 'onger', 'vinced', 'eign', 'soun', 'unsnarled', 'proce', 'cisive', 'livside', 'dictograph', 'painsremoving', 'diefoyer', 'laste', 'whispe', 'methu', 'contrabeam', 'allf', 'sandcolored', 'coupes', 'vind', 'imho', 'losive', 'str', 'ingmartin', 'windv', 'abc', 'starin', 'thankless', 'drudging', 'rtin', 'movedlike', 'tago', 'howdid', 'tiltawhirl', 'artin', 'wholesomely', 'frozenaction', 'fart', 'videodirectory', 'assertive', 'tvt', 'raima', 'whci', 'watche', 'pedes', 'uizling', 'beeach', 'teleof', 'rous', 'rinmn', 'tndicatin', 'irks', 'hatchetwornan', 'highblown', 'blatz', 'raimu', 'raimus', 'naiads', 'brightlost', 'perila', 'ousness', 'whas', 'comthe', 'upas', 'wgnt', 'getblack', 'feelclever', 'unconnude', 'doorshaved', 'cagey', 'omebody', 'tamil', 'furiny', 'tarau', 'kittenandmicing', 'tarnu', 'sullenfaced', 'silkcovered', 'fragilelegged', 'wajted', 'plhnet', 'imitless', 'isexactly', 'xst', 'fison', 'treme', 'amu', 'ecu', 'wellmasked', 'atcher', 'perjured', 'cameto', 'mythoxians', 'comnion', 'guinevere', 'shalot', 'mythoxian', 'straightleft', 'yoiire', 'handywork', 'airsled', 'lma', 'theydid', 'sharplv', 'orins', 'hud', 'heiner', 'rnood', 'havetwo', 'somevi', 'rst', 'spains', 'zoins', 'ermg', 'omg', 'sounc', 'foarre', 'doggedsaid', 'hout', 'niek', 'gbt', 'uminum', 'yourworry', 'exhappy', 'smerin', 'chalkmark', 'dawa', 'fempted', 'checkthe', 'nosepiece', 'escapehole', 'pitchdarkness', 'xmy', 'jua', 'neauty', 'sne', 'herse', 'klias', 'phoenician', 'resence', 'willa', 'prealmost', 'humorspeculation', 'grfals', 'rorrck', 'nonsleepers', 'findher', 'owy', 'ightly', 'natura', 'bodyweight', 'plainrimmed', 'sweeewhew', 'thoughtaura', 'kfias', 'loveaffair', 'jaywalked', 'thoughtnot', 'grandiloquence', 'snarlecl', 'venomgun', 'thirder', 'consciousnesspatterns', 'taxidriver', 'grimlipped', 'policewhistle', 'cabby', 'pastorals', 'braceleted', 'skve', 'ayoyo', 'ironhe', 'phoenicis', 'klidds', 'algum', 'ironless', 'spaceforce', 'uing', 'youryou', 'yomre', 'provin', 'nicis', 'tfc', 'tobelongings', 'earshocking', 'hydrian', 'leadbawled', 'everying', 'tinue', 'nonspacegoing', 'fleshwound', 'latently', 'emotionpatterns', 'inventives', 'terranpattems', 'securityseekers', 'knowledgeseekers', 'gloryseekers', 'nonthreat', 'thoughtprojective', 'gauntness', 'recordequations', 'taxrates', 'reinvesting', 'advancements', 's ...

# %% [markdown]
# # **Predict top 5 closest words by model trained on scifi**

# %%
# top 5 closest words predicted by model trained on scifi
chosen_scifi_words = ['hand','good','know','cup','amazing','aid','timetables','thankless','trys']
for word in chosen_scifi_words:
  print("{}:{}".format(word, scifi_words_dict[word]))
  get_closest_word(model_scifi, idx_to_word_scifi, word_to_idx_scifi[word])
  print('\n')
# Out:
# hand:10996
# ['shoulder', 'hands', 'finger', 'heart', 'chin']
#
#
# good:15435
# ['fine', 'bad', 'great', 'nice', 'small']
#
#
# know:28539
# ['mean', 'understand', 'think', 'say', 'remember']
#
#
# cup:596
# ['pack', 'stream', 'bag', 'bottle', 'flare']
#
#
# amazing:528
# ['impossible', 'possible', 'imperfect', 'rapid', 'abrupt']
#
#
# aid:679
# ['violence', 'victory', 'satisfaction', 'fear', 'fugue']
#
#
# timetables:1
# ['ally', 'absurdly', 'intending', 'rousseau', 'tickets']
#
#
# thankless:4
# ['ecological', 'quantum', 'highpower', 'screwing', 'antiaircraft']
#
#
# trys:2
# ['gibson', 'kaifri', 'everything', 'vix', 'resigned']

# %% [markdown]
# # **Looking for common words in the two corpus**

# %%
# looking for common words in scifi and reviews
#common_words = []
#for word in set(high_rev).intersection(set(high_sci)):
  #common_words.append(word)
#print(common_words)

word_dic_rev = set(reviews.count_word)
word_dic_scifi = set(scifi.count_word)
print("Common words and their frequency in scifi and tripadvisor hotel reviews:")
common_words =[]
for word in word_dic_rev.intersection(word_dic_scifi):
  if word!='' and reviews.count_word[word]>5000 and scifi.count_word[word]>5000:
    common_words.append([word, reviews.count_word[word], scifi.count_word[word]])
print(common_words)
# Out:
# Common words and their frequency in scifi and tripadvisor hotel reviews:
# [['really', 7765, 7108], ['room', 34324, 10662], ['did', 13895, 22897], ['small', 6527, 8346], ['night', 9729, 6149], ['not', 31526, 70746], ['day', 9542, 8679], ['like', 8114, 35710], ['good', 16986, 15435], ['no', 11620, 50173], ['place', 7693, 8730], ['great', 21094, 8308], ['time', 9824, 31971], ['people', 6762, 13190], ['just', 12592, 27961], ['little', 6242, 17199], ['got', 6186, 17900]]

# %% [markdown]
# # **Predict top 3 closest words for certain common words by the two models**

# %%
# choose common words from both files, predicted closest words by the two models
chosen_common_words = ['day','place','good']
print('----Predicted by model trained on <scifi.txt>----')
for word in chosen_common_words:
  print("{}:{}".format(word, scifi_words_dict[word]))
  get_closest_word(model_scifi, idx_to_word_scifi, word_to_idx_scifi[word],topn=3)
  print('\n')

print('----Predicted by model trained on <tripadvisor_hotel_reviews.txt>----')
for word in chosen_common_words:
  print("{}:{}".format(word, rev_words_dict[word]))
  get_closest_word(model_rev, idx_to_word_rev, word_to_idx_rev[word], topn=3)
  print('\n')
# Out:
# ----Predicted by model trained on <scifi.txt>----
# day:8679
# ['time', 'night', 'world']
#
#
# place:8730
# ['world', 'country', 'town']
#
#
# good:15435
# ['fine', 'bad', 'great']
#
#
# ----Predicted by model trained on <tripadvisor_hotel_reviews.txt>----
# day:9542
# ['everyday', 'week', 'days']
#
#
# place:7693
# ['hotel', 'resort', 'overall']
#
#
# good:16986
# ['great', 'fine', 'excellent']
